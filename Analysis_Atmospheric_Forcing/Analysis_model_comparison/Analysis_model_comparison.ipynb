# %% [markdown]
# # Large-Scale Comparison between HRDPS and CaSR
#
# In this notebook, we compare the spatial and temporal difference of HRDPS and CaSR in general, including variables that may impact physical and biological processes, including wind speed and its auto-corelation, wind stress curl and heat flux, if possible. They affect water column stability.

# %% [markdown]
# ## Basic Preparation
