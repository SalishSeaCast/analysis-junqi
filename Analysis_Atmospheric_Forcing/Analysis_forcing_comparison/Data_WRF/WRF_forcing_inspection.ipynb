# %% [markdown]
# # 1km resolution WRF Inspection

# %% [markdown]
# ## Variables

# %%
# load and print

import xarray as xr

path='/ocean/rich/home/Data_Downloads/WFRT_RDPS-WRF/WAC00WG-01_d03_250529.nc'

ds_WRF=xr.load_dataset(path)

print(ds_WRF)
# Out:
# <xarray.Dataset> Size: 35MB
# Dimensions:  (XTIME: 25, south_north: 486, west_east: 351)
# Coordinates:
#   * XTIME    (XTIME) datetime64[ns] 200B 2025-05-29T09:00:00 ... 2025-05-30T0...
#     XLONG    (south_north, west_east) float32 682kB -124.5 -124.5 ... -124.2
#     XLAT     (south_north, west_east) float32 682kB 46.65 46.66 ... 52.97 52.97
# Dimensions without coordinates: south_north, west_east
# Data variables:
#     u_earth  (XTIME, south_north, west_east) float32 17MB 0.9631 ... -0.2429
#     v_earth  (XTIME, south_north, west_east) float32 17MB 8.987 9.017 ... 1.459
# Attributes: (12/139)
#     CDI:                             Climate Data Interface version 1.9.8 (ht...
#     history:                         Sun Jun 01 14:36:31 2025: cdo merge u_wi...
#     Conventions:                     CF-1.6
#     TITLE:                            OUTPUT FROM WRF V4.2.1 MODEL
#     START_DATE:                      2025-05-29_07:00:00
# ...

# %% [markdown]
# **Only Wind! Maybe consider it later. Or maybe use WRF wind + HRDPS other variables?**
