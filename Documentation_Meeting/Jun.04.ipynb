# %% [markdown]
# # Weekly Meeting on June 4

# %% [markdown]
# ## Observation at Sentry Shoal, Pam Rock, Halibut and Sandheads
#
# See https://github.com/SalishSeaCast/analysis-junqi/blob/main/Analysis_Atmospheric_Forcing/Analysis_model_vs_observation/Wind_Model_vs_Obs.ipynb
#
# ### Wind direction and spees
#
# 1. Wind data of models and observations in 2018 match well at Sentry Shoal, Halibut and Sandheads.
#
# 2. Observational wind speed is much higher (~2 times?) than model data at Pam Rocks.
#
# 3. Wind roses have different dominant directions among 3 datasets at Pam Rocks.
#
# ### Wind frequency analysis
#
# Match quite well?

# %% [markdown]
# ## Wind Stress Curl comparison among models
#
# See https://github.com/SalishSeaCast/analysis-junqi/blob/main/Analysis_Atmospheric_Forcing/Analysis_model_comparison/Wind%20Curl.ipynb.
#
# 3 kinds of datasets: HRDPS, CaSR and coarsened HRDPS (the mean of 4 points)

# %% [markdown]
# ## To Do
#
# ### Obs
# split summer and winter especially at Pam Rocks. We expect to see different directions of the strong winds but the accuracy would still be as bad.
#
# ### For wind speed squared and cubed?
#
# For mixing, see wind speed cubed;
#
# For stress, see wind speed squared.
#
# Also pick 1 point out of 4 instead of averaging.
#
#
# ### Short wave solar radiation
#
# Biological important.
#
# ### Generate an CaSR_operational forcing field
#
# See GEM2.5/operational, find any date, and see what it looks like. Same variable names, and see what else is needed.
#
# Should call it CaSR_y2018...
