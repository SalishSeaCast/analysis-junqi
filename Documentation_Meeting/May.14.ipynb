# %% [markdown]
# # Weekly Meeting on April.23

# %% [markdown]
# ## Report
#
# The units have been corrected and a new figure of Nitrate was added.
#
#
# ![nitrate_section.png](attachment:nitrate_section.png)
# Figure. Sections of nitrate concentration distributions before and after the storm across Salish Sea in 2011 and 2018. Grey areas represent seabeds and lands, yellow-blue colour denotes Nitrate concentration (mmol m$^{-3}$). A strong storm towards north-west occurred during July 9 to July 17 in 2011, while another one towards south-west occurred during July 9 to July 17 in 2018.
#
#
# ![image.png](attachment:image.png)
#
# Figure. Sections of nitrate concentration distributions before and during the beginning (July 9 - July 11) of the storm across Salish Sea in 2011 and 2018. Grey areas represent seabeds and lands, yellow-blue colour denotes Nitrate concentration (mmol m$^{-3}$).
#
# The nitrate responses were obvious in the first few days of the storm, but the signals were not as obvious at the end of the storms.
#
#
# Which one to include?
#
# See https://www.overleaf.com/project/69e026cff87f50f1f4989990.

# %% [markdown]
# ## PRODIGY
#
# Glider, Drifter, Floats and Mooring.
#
# Lots of turbulence measuring.
#
# Glider: https://canva.link/dfl86tnzxmgzh2o

# %% [markdown]
# ## Atmospheric Forcing
#
# | Station Name | Source                            | Station ID | Latitude | Longitude |
# |--------------|-----------------------------------|------------|----------|-----------|
# | Sandheads    | Environment and natural resources | 6831       | 49.11    | -123.3    |
# | Halibut Bank | Fisheries and Oceans              | --         | --       | --        |
# | Pam Rocks    | Environment and natural resources | 6817       | 49.49    | -123.3    |
# | Sentry Shoal | Fisheries and Oceans              | --         | --       | --        |
#
# Buoy data can be a bit hard to find?

# %% [markdown]
# ## Feedback
#
# ### Report
#
# Overall nitrate difference in 2018 and 2011, even before the storm. The storm may disturb the set nutrient/productivity regime.
#
# ### Buoy Data
#
# read .fb file and may find it.

# %% [markdown]
# ## To Do
#
# 1. Reading.
#
# 2. Creating some Python Toolkit.
#
# 3. Wind data comparison: observation vs models.
#
# 4. There is another even courser atmospheric forcing model, see slack.

# %% [markdown]
# ## Follow up
#
# ### Reading
#
# Paul G. Myers's *Sensitivity of Labrador Sea Water Formation to Changes in Model Resolution, Atmospheric Forcing, and Freshwater Input*
#
# 1. Temporal frequency of the forcing field impacts the results a lot, through high-frequency atmospheric phenomena.
#
#     'We found that by filtering out such events (smoothed with a 10-day window) the heat loss over the Labrador Sea decreases by 44%.'
#
# 2. Heat flux and buoyancy fluxes are different among models.
#
#     'Figure 7 shows higher transport of IW (Figure 7a) and freshwater (Figure 7b) from the WGC directly into our study region, in SPG12 compared to Control. A larger thermal forcing component (heat loss only in this case) of the buoyancy fluxes (Figure 7c) in SPG12 especially in fall and winter appears to follow the larger advection of IW in this simulation compared to Control.'
#
# **What we can do**
#
# See if we could calculate the difference of the wind velocity, wind stress curl and heat flux (not sure how to calculate it). Wind velocity influences wind mixing, wind stress curl influences upwelling, and heat flux (as well as fresh water input) influences the stratification or buoyancy fluxes.
#
# Spatially, we may observe the differences in regions strongly affected by terrains, while temporally, we may explore if there is delay of high wind velocity or heat flux.
