# %% [markdown]
# # The Time Series of Diatom and Flagellate in Salish Sea

# %% [markdown]
# In this notebook, we will explore how the amount of diatom and flagellate in the upper ocean, maybe to 20 meters, changes every month and see if it's influenced by the NPGO index.
